# %%
from pymongo import MongoClient
import json
from datetime import datetime
import pandas as pd

# %%
# DB configuration

mongo_uri = "mongodb+srv://umair:umairmongo@cluster0.pgkqn44.mongodb.net/?retryWrites=true&w=majority"

database_name = "GST_Check"
collection_name = "GST"

client = MongoClient(mongo_uri)
database = client[database_name]
collection_GST = database[collection_name]

# %%
file_path='GST.json'

# %%
# Load the JSON file
with open(file_path, 'r') as json_file:
    records_data = json.load(json_file)

# Add "updated_at" field to all records
updated_at_timestamp = datetime.utcnow().isoformat()

records_data["updated_at"]=updated_at_timestamp
# for record in records_data:
#     record["updated_at"] = updated_at_timestamp

# %%
records_data
# Out:
# {'pan': 'AAACR5055K',
#  'hsn': ['00440116', '00440060', '00440366', '00440480', '00440153'],
#  'compCategory': 'Yellow',
#  'dty': 'Regular',
#  'lgnm': 'Reliance Industries Limited',
#  'pincode': '400701',
#  'sts': 'Active',
#  'tradeName': 'Reliance Industries Limited',
#  'gstin': '27AAACR5055K2Z6',
#  'mandatedeInvoice': 'Yes',
#  'einvoiceStatus': 'Yes',
#  'ctb': 'Public Limited Company',
#  'aggreTurnOverFY': 'Available in Paid Version of API',
#  'aggreTurnOver': 'Available in Paid Version of API',
#  'rgdt': '28/06/2017',
#  'nba': ['Recipient of Goods or Services',
#   'Supplier of Services',
#   'Export',
#   'Office / Sale Office',
#   'Import'],
#  'cxdt': '',
#  'ctj': 'Commissionerate - BELAPUR,Division - DIVISION IV,Range - RANGE-IV (Jurisdictional Office)',
#  'stj': 'State - Maharashtra,Zone - Thane,Division - RAIGAD,Charge - URAN_701',
# ...

# %%
# Fetch documents where GSTIN is "1234"
query = {"gstin": "24AAACR5055K1ZD"}
result = collection_GST.find(query)

# Print or process the fetched documents
returns=[]
for document in result:
    returns=document["returns"]

# %%
returns
# Out:
# [{'fy': '2023-2024', 'dof': '11/08/2023', 'rtntype': 'GSTR1', 'taxp': 'July'},
#  {'fy': '2023-2024', 'dof': '11/07/2023', 'rtntype': 'GSTR1', 'taxp': 'June'},
#  {'fy': '2023-2024', 'dof': '10/06/2023', 'rtntype': 'GSTR1', 'taxp': 'May'},
#  {'fy': '2023-2024', 'dof': '10/05/2023', 'rtntype': 'GSTR1', 'taxp': 'April'},
#  {'fy': '2022-2023', 'dof': '11/04/2023', 'rtntype': 'GSTR1', 'taxp': 'March'},
#  {'fy': '2022-2023',
#   'dof': '11/03/2023',
#   'rtntype': 'GSTR1',
#   'taxp': 'February'},
#  {'fy': '2022-2023',
#   'dof': '11/02/2023',
#   'rtntype': 'GSTR1',
#   'taxp': 'January'},
#  {'fy': '2022-2023',
#   'dof': '10/01/2023',
#   'rtntype': 'GSTR1',
#   'taxp': 'December'},
#  {'fy': '2022-2023',
#   'dof': '11/12/2022',
#   'rtntype': 'GSTR1',
#   'taxp': 'November'},
#  {'fy': '2022-2023',
#   'dof': '10/11/2022',
#   'rtntype': 'GSTR1',
#   'taxp': 'October'},
#  {'fy': '2023-2024', 'dof': '20/07/2023', 'rtntype': 'GSTR3B', 'taxp': 'June'},
# ...

# %%
# Create a dictionary to store records based on rtntype
rtntype_data = {}
for record in returns:
    rtntype = record['rtntype']
    if rtntype not in rtntype_data:
        rtntype_data[rtntype] = []
    rtntype_data[rtntype].append(record)

# Print or use the separated data
for rtntype, records in rtntype_data.items():
    print(f"Records for rtntype {rtntype}:")
    for record in records:
        print(record)
    print("\n")
# Out:
# Records for rtntype GSTR1:
# {'fy': '2023-2024', 'dof': '11/08/2023', 'rtntype': 'GSTR1', 'taxp': 'July'}
# {'fy': '2023-2024', 'dof': '11/07/2023', 'rtntype': 'GSTR1', 'taxp': 'June'}
# {'fy': '2023-2024', 'dof': '10/06/2023', 'rtntype': 'GSTR1', 'taxp': 'May'}
# {'fy': '2023-2024', 'dof': '10/05/2023', 'rtntype': 'GSTR1', 'taxp': 'April'}
# {'fy': '2022-2023', 'dof': '11/04/2023', 'rtntype': 'GSTR1', 'taxp': 'March'}
# {'fy': '2022-2023', 'dof': '11/03/2023', 'rtntype': 'GSTR1', 'taxp': 'February'}
# {'fy': '2022-2023', 'dof': '11/02/2023', 'rtntype': 'GSTR1', 'taxp': 'January'}
# {'fy': '2022-2023', 'dof': '10/01/2023', 'rtntype': 'GSTR1', 'taxp': 'December'}
# {'fy': '2022-2023', 'dof': '11/12/2022', 'rtntype': 'GSTR1', 'taxp': 'November'}
# {'fy': '2022-2023', 'dof': '10/11/2022', 'rtntype': 'GSTR1', 'taxp': 'October'}
#
#
# Records for rtntype GSTR3B:
# {'fy': '2023-2024', 'dof': '20/07/2023', 'rtntype': 'GSTR3B', 'taxp': 'June'}
# ...

# %%
import pandas as pd


# Key-Value Dictionary
Dict3 = {'2021-2022': '31/12/2022',
         '2020-2021': '28/02/2022',
         '2019-2020': '31/03/2021',
         '2018-2019': '31/12/2020',
         '2017-2018': '12/02/2020'}

# Update the 'check' key and value in the JSON data
returns_data = json_data.get("returns", [])
for return_obj in returns_data:
    fy = return_obj.get("fy", "")
    dof = return_obj.get("dof", "")
    filing_date = pd.to_datetime(Dict3.get(fy, ""), format='%d/%m/%Y')
    return_obj["check"] = 'Delayed' if pd.to_datetime(dof, format='%d/%m/%Y') > filing_date else 'On time'

# Create DataFrame
df = pd.DataFrame(returns_data)

# Display the DataFrame
print(df)


# Create a dictionary to store records based on rtntype
rtntype_data = {}
for record in returns:
    rtntype = record['rtntype']
    if rtntype not in rtntype_data:
        rtntype_data[rtntype] = []
    
    # Remove the 'rtntype' key and add the 'check' field
    record.pop('rtntype', None)
    dof_day = int(record['dof'].split('/')[0])
    record['check'] = 'Delayed' if dof_day > 15 else 'On time'

    rtntype_data[rtntype].append(record)

# Print or use the modified data
for rtntype, records in rtntype_data.items():
    print(f"Records for rtntype {rtntype}:")
    for record in records:
        print(record)
    print("\n")
# Out:
# Records for rtntype GSTR1:
# {'fy': '2023-2024', 'dof': '11/08/2023', 'taxp': 'July', 'check': 'On time'}
# {'fy': '2023-2024', 'dof': '11/07/2023', 'taxp': 'June', 'check': 'On time'}
# {'fy': '2023-2024', 'dof': '10/06/2023', 'taxp': 'May', 'check': 'On time'}
# {'fy': '2023-2024', 'dof': '10/05/2023', 'taxp': 'April', 'check': 'On time'}
# {'fy': '2022-2023', 'dof': '11/04/2023', 'taxp': 'March', 'check': 'On time'}
# {'fy': '2022-2023', 'dof': '11/03/2023', 'taxp': 'February', 'check': 'On time'}
# {'fy': '2022-2023', 'dof': '11/02/2023', 'taxp': 'January', 'check': 'On time'}
# {'fy': '2022-2023', 'dof': '10/01/2023', 'taxp': 'December', 'check': 'On time'}
# {'fy': '2022-2023', 'dof': '11/12/2022', 'taxp': 'November', 'check': 'On time'}
# {'fy': '2022-2023', 'dof': '10/11/2022', 'taxp': 'October', 'check': 'On time'}
#
#
# Records for rtntype GSTR3B:
# {'fy': '2023-2024', 'dof': '20/07/2023', 'taxp': 'June', 'check': 'Delayed'}
# ...

# %%
# Convert the data to a DataFrame
df = pd.DataFrame(returns)

# Separate data based on different rtntype
rtntype_tables = {}
# for rtntype, group in df.groupby("rtntype"):
#     rtntype_tables[rtntype] = group.drop("id", axis=1)  # Drop the MongoDB _id field

# Display or use the tables as needed
for rtntype, table in df.groupby("rtntype").items():
    print(f"Table for rtntype: {rtntype}")
    print(table)
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\umair\Downloads\EMP_GST\research\data_upload.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/umair/Downloads/EMP_GST/research/data_upload.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> rtntype_tables = {}
#       <a href='vscode-notebook-cell:/c%3A/Users/umair/Downloads/EMP_GST/research/data_upload.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> # for rtntype, group in df.groupby("rtntype"):
#       <a href='vscode-notebook-cell:/c%3A/Users/umair/Downloads/EMP_GST/research/data_upload.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> #     rtntype_tables[rtntype] = group.drop("id", axis=1)  # Drop the MongoDB _id field
#       <a href='vscode-notebook-cell:/c%3A/Users/umair/Downloads/EMP_GST/research/data_upload.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>
# ...

# %%
df.groupby("rtntype")
